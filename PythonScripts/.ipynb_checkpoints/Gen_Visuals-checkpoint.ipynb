# %% [markdown]
# ### Generate results

# %%
# %run prevalence_ww.py
# Out:
# [array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         3.37370624e+04, 3.35929103e+04, 3.34580184e+04],
#        [0.00000000e+00, 6.67414824e-01, 8.89886432e-01, ...,
#         5.71899850e+04, 5.69159797e+04, 5.64732969e+04],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.64272286e+05, 1.57958037e+05, 1.51888746e+05],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         4.21411966e+03, 4.09924732e+03, 3.99422306e+03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         6.75874636e+00, 6.64030612e+00, 6.50255102e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.69096210e+00, 1.62244898e+00, 1.53826531e+00]]), array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         3.87866929e+04, 3.86209646e+04, 3.84658827e+04],
#        [0.00000000e+00, 9.30335816e-01, 1.24044775e+00, ...,
#         6.77126925e+04, 6.73882715e+04, 6.68641369e+04],
# ...

# %% [markdown]
# ### Generate Visualizations

# %%
import pickle 
with open("../Output_Pickles/true_new_infec_ww.pkl", "rb") as f:
    true_new_infec_ww = pickle.load(f)
with open("../Output_Pickles/true_new_infec_final.pkl", "rb") as f:
    true_new_infec = pickle.load(f)

# %%
weekly_TIF = true_new_infec[0].rolling(7, axis=1).sum().iloc[:,range(0,true_new_infec[0].shape[1],7)]

# %%
ys = np.sum(weekly_TIF,axis=0)
xs = list(weekly_TIF.columns)

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xs,ys, linestyle = 'dotted')
plt.show()
