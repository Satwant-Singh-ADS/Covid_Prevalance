# %%
from latest_us_data import *

# %%
#get_data()
# Out:
# [[1.0000000e+00 1.0000000e+00 1.0000000e+00 ... 1.9041980e+06
#   1.9041980e+06 1.9097730e+06]
#  [0.0000000e+00 1.0000000e+00 1.0000000e+00 ... 4.0197680e+06
#   4.0197680e+06 4.0299050e+06]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 1.1998032e+07
#   1.1999615e+07 1.2005616e+07]
#  ...
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 6.3454100e+05
#   6.3485300e+05 6.3513200e+05]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 1.3503000e+04
#   1.3503000e+04 1.3503000e+04]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 8.3200000e+03
#   8.3200000e+03 8.3200000e+03]]

# %%
pickle.load()

# %%
import pandas as pd

# %%
import numpy as np

# %%
sel_url = 'https://raw.githubusercontent.com/biobotanalytics/covid19-wastewater-data/master/wastewater_by_county.csv';
# # urlwrite(sel_url, 'dummy.csv');
# # ww_data = readtable('dummy.csv');

ww_data = pd.read_csv(sel_url)

# %%
popu = pd.read_csv("us_states_population_data.txt",header=None)

# %%
abvs = list(pd.read_csv("us_states_abbr_list.txt",header=None)[0].values)

# %%
fips_tab = pd.read_csv("reich_fips.txt")
# abbreviation      object
# location          object
# location_name     object
# population       float64

# %%
data_4_tmp = pd.read_csv("data_4.csv",header=None)

# %%
data_4 = data_4_tmp.to_numpy()

# %%
def impute_us(x):
    if x=='US':
        return '0'
    else:
        return x
fips_tab['location'] = fips_tab['location'].apply(impute_us)

# %%
ww_data['fipscode'].dtype
# Out:
# dtype('O')

# %%
ww_data['fipscode'] = ww_data.fipscode.astype(str)

# %%
mapped_values = pd.merge(ww_data,fips_tab.reset_index(),how='left', left_on='fipscode', right_on='location')

import math

aa_fips_idx = []
for w in [list(mapped_values['index'].values)][0]:
    if math.isnan(w):
        aa_fips_idx.append([1,0])
    else:
        aa_fips_idx.append([1,w])

# %%
xx = ww_data.sampling_week

# %%
whichday = np.zeros(len(xx)).reshape(len(xx),1)

# %%
whichday.shape
# Out:
# (11153, 1)

# %%
# date_string = '2021-12-31'
# datetime = datetime.strptime(date_string, '%Y-%m-%d')

# %%
xx[0]
# Out:
# '2020-01-01'

# %%
from datetime import datetime
# date_format = "%y-%mm-%dd"
b = datetime.strptime('2020-01-23', '%Y-%m-%d')

# %%
for i in range(len(whichday)):
    a = datetime.strptime(xx[i],'%Y-%m-%d')
    delta = a-b
    whichday[i] = int(delta.days)

# %%
whichday.max()
# Out:
# 1049.0

# %%
ww_ts = np.zeros(data_4.shape)
ww_pres =  np.zeros(data_4.shape)

# %%
ww_pres.shape
# Out:
# (56, 1019)

# %%
ww_data['state']
# Out:
# array(['IL', 'MA', 'CA', 'CO', 'NJ', 'FL', 'IN', 'OR', 'KY', 'PA', 'MT',
#        'CT', 'DE', 'OK', 'WY', 'AZ', 'MN', 'NY', 'VA', 'HI', 'ID', 'NV',
#        'TN', 'ME', 'WA', 'RI', 'VT', 'SD', 'VI', 'AR', 'MO', 'NC', 'TX',
#        'NM', 'GA', 'AL', 'WV', 'KS', 'NH', 'WI', 'LA', 'SC', 'MI', 'UT',
#        'MS', 'OH', 'IA', 'DC', 'MD', 'NE', 'ND', 'AK'], dtype=object)

# %%
aa_abvs_idx = []
for w in ww_data['state']:
        aa_abvs_idx.append([1,abvs.index(w)])

# %%
for ii in range(len(xx)):
    if whichday[ii]<1 or aa_fips_idx[ii][1] < 0:
        continue
    ww_pres[aa_abvs_idx[ii][1],int(whichday[ii][0])] = 1
#     ww_ts[aa_abvs_idx[ii][1],int(whichday[ii][0])] = ww_ts[aa_abvs_idx[ii][1],int(whichday[ii][0])] \
#     + ww_data['effective_concentration_rolling_average'][ii]*fips_tab['population'][ii]*popu[0][aa_abvs_idx[ii][1]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [183], line 4
#       2 if whichday[ii]<1 or aa_fips_idx[ii][1] < 0:
#       3     continue
# ----> 4 ww_pres[aa_abvs_idx[ii][1],int(whichday[ii][0])] = 1
#
# IndexError: index 1021 is out of bounds for axis 1 with size 1019

# %%
for ii in range(len(xx)):
    if whichday[ii]<1 or aa_fips_idx[ii][1] < 0:
        continue
    try:
        ww_pres[aa_abvs_idx[ii][1],int(whichday[ii][0])] = 1
        ww_ts[aa_abvs_idx[ii][1],int(whichday[ii][0])] = ww_ts[aa_abvs_idx[ii][1],int(whichday[ii][0])] \
        + ww_data['effective_concentration_rolling_average'][ii]*fips_tab['population'][ii]*popu[0][aa_abvs_idx[ii][1]]
    except:
        print(ii)
# Out:
# 3200
# 3201
# 3202
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3218
# 3219
# 3220
# 3221
# 3222
# 3223
# 3224
# 3225
# 3226
# 3227
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3239
# 3240
# 3241
# 3242
# 3243
# 3244
# 3245
# 3246
# 3247
# 3248
# 3249
# 3250
# 3251
# 3252
# 3253
# 3254
# 3255
# 3256
# 3257
# 3258
# 3259
# 3260
# 3261
# 3262
# 3263
# 3264
# 3265
# 3266
# 3267
# 3268
# 3269
# 3270
# 3271
# 3272
# 3273
# 3274
# 3275
# 3276
# 3277
# 3278
# 3279
# 3280
# 3281
# 3282
# 3283
# 3284
# 3285
# 3286
# 3287
# 3288
# 3289
# 3290
# 3291
# 3292
# 3293
# 3294
# 3295
# 3296
# 3297
# 3298
# 3299
# 3300
# 3301
# 3302
# 3303
# 3304
# 3305
# 3306
# 3307
# 3308
# 3309
# 3310
# 3311
# 3312
# 3313
# 3314
# 3315
# 3316
# 3317
# 3318
# 3319
# 3320
# 3321
# 3322
# 3323
# 3324
# 3325
# 3326
# 3327
# 3328
# 3329
# 3330
# 3331
# 3332
# 3333
# 3334
# 3335
# 3336
# 3337
# 3338
# 3339
# 3340
# 3341
# ...

# %%
ii
# Out:
# 3

# %%
ww_ts[aa_abvs_idx[ii][1],int(whichday[ii][0])]
# Out:
# 0.0

# %%
ww_data['effective_concentration_rolling_average'][ii]
# Out:
# 0.0

# %%
fips_tab['population'][ii]
# Out:
# 7278717.0

# %%
aa_abvs_idx[ii]
# Out:
# [1, 4]

# %%
popu[0][aa_abvs_idx[ii][1]]
# Out:
# 1    12671821
# 4     6949503
# Name: 0, dtype: int64

# %%
ww_data['effective_concentration_rolling_average'][ii]*fips_tab['population'][ii]*popu[0][aa_abvs_idx[ii]]
# Out:
# 1    0.0
# 4    0.0
# Name: 0, dtype: float64

# %%
#  ww_data['effective_concentration_rolling_average'][0]
# Out:
# 134.84196356544973

# %%
ww_data
# Out:
#        Unnamed: 0 sampling_week  effective_concentration_rolling_average  \
# 0               0    2020-01-01                               134.841964
# 1               1    2020-01-15                                 0.000000
# 2               2    2020-01-22                                 0.000000
# 3               3    2020-01-29                                 0.000000
# 4               4    2020-02-05                                 0.000000
# ...           ...           ...                                      ...
# 11148       11308    2022-12-07                              1165.728025
# 11149       11309    2022-12-07                               662.172806
# 11150       11310    2022-12-07                               450.558392
# 11151       11311    2022-12-07                              1147.608947
# 11152       11312    2022-12-07                               403.683372
#
#           region state                  name fipscode
# ...

# %%
# for ii=1:length(xx)
#     if whichday(ii) < 1 || fips_idx(ii) < 1
#         continue;
#     end
#     ww_pres(abvs_idx(ii), whichday(ii)) = 1;
#     ww_ts(abvs_idx(ii), whichday(ii)) = ww_ts(abvs_idx(ii), whichday(ii)) ...
#         + ww_data.effective_concentration_rolling_average(ii)*fips_tab.population(fips_idx(ii))/popu(abvs_idx(ii));
# end
